# %%
import pandas as pd

# %%
pd.read_csv("shanghaiData.csv")
# Out:
#      world_rank                                    university_name  \
# 0             1                                 Harvard University
# 1             2                            University of Cambridge
# 2             3                                Stanford University
# 3             4                 University of California, Berkeley
# 4             5        Massachusetts Institute of Technology (MIT)
# 5             6                 California Institute of Technology
# 6             7                                Columbia University
# 7             8                               Princeton University
# 8             9                              University of Chicago
# 9            10                               University of Oxford
# 10           11                                    Yale University
# 11           12                                 Cornell University
# 12           13                University of California, San Diego
# ...
